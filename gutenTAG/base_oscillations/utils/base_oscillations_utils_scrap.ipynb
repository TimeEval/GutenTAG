# %%
import numpy as np
from math_func_support import prepare_base_signal, generate_periodic_signal, calc_n_periods
import gutenTAG.utils.default_values
import matplotlib as plt

# %%
bs = prepare_base_signal(1000,100)

# %%
type(bs)
# Out:
# numpy.ndarray

# %%
np.shape(bs)
# Out:
# (1000,)

# %%
periodic_signal = generate_periodic_signal(bs,np.sin,1.0,10)

# %%
type(periodic_signal)
# Out:
# numpy.ndarray

# %%
np.shape(periodic_signal)
# Out:
# (1000,)

# %%
type(np.shape(periodic_signal))
# Out:
# tuple

# %%
len(np.shape(periodic_signal))
# Out:
# 1

# %%
plt.pyplot.plot(periodic_signal)

# %%
my_tuple = 1,

# %%
my_tuple
# Out:
# (1,)
